# %%
import datasets
import lib.util

# %%
ds = datasets.load_dataset('beans', cache_dir='data')
lib.util.show_examples(ds)
# Out:
# Found cached dataset beans (/Users/yabie/Desktop/challenge/data/beans/default/0.0.0/90c755fb6db1c0ccdad02e897a37969dbf070bed3755d4391e269ff70642d791)
# ...
#   0%|          | 0/2 [00:00<?, ?ba/s]
# <PIL.Image.Image image mode=RGB size=1050x1050>
